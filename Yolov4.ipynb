# %% [markdown]
# darknetをDriveにインストール

# %%
# %cd /content/drive/My\ Drive
# !git clone https://github.com/AlexeyAB/darknet

# %% [markdown]
# コンパイル

# %%
# %cd /content/drive/My\ Drive/darknet
# !make

# %% [markdown]
# GPUの確認

# %%
# !nvidia-smi

# %% [markdown]
# train - testの切り分け

# %%
# %cd /content/drive/My\ Drive/darknet/data
# !python process.py

# %% [markdown]
# 学習開始

# %%
# %cd /content/drive/My\ Drive/darknet
# !./darknet detector\
  train\
  data/obj.data\
  cfg/yolov4-obj.cfg\
  yolov4.conv.137\
  -map\
  -dont_show

# %% [markdown]
# 学習再開

# %%
# !./darknet detector\
  train\
  data/obj.data\
  cfg/yolov4-obj.cfg\
  backup/yolov4-obj_last.weights\
  -map\
  -dont_show
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  Prepare additional network for mAP calculation...
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 32, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    640 x 480 x   3 ->  640 x 480 x  32 0.531 BF
#    1 conv     64       3 x 3/ 2    640 x 480 x  32 ->  320 x 240 x  64 2.831 BF
#    2 conv     64       1 x 1/ 1    320 x 240 x  64 ->  320 x 240 x  64 0.629 BF
#    3 route  1 		                           ->  320 x 240 x  64
#    4 conv     64       1 x 1/ 1    320 x 240 x  64 ->  320 x 240 x  64 0.629 BF
#    5 conv     32       1 x 1/ 1    320 x 240 x  64 ->  320 x 240 x  32 0.315 BF
#    6 conv     64       3 x 3/ 1    320 x 240 x  32 ->  320 x 240 x  64 2.831 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 320 x 240 x  64 0.005 BF
#    8 conv     64       1 x 1/ 1    320 x 240 x  64 ->  320 x 240 x  64 0.629 BF
#    9 route  8 2 	                           ->  320 x 240 x 128
#   10 conv     64       1 x 1/ 1    320 x 240 x 128 ->  320 x 240 x  64 1.258 BF
#   11 conv    128       3 x 3/ 2    320 x 240 x  64 ->  160 x 120 x 128 2.831 BF
#   12 conv     64       1 x 1/ 1    160 x 120 x 128 ->  160 x 120 x  64 0.315 BF
#   13 route  11 		                           ->  160 x 120 x 128
#   14 conv     64       1 x 1/ 1    160 x 120 x 128 ->  160 x 120 x  64 0.315 BF
#   15 conv     64       1 x 1/ 1    160 x 120 x  64 ->  160 x 120 x  64 0.157 BF
#   16 conv     64       3 x 3/ 1    160 x 120 x  64 ->  160 x 120 x  64 1.416 BF
#   17 Shortcut Layer: 14,  wt = 0, wn = 0, outputs: 160 x 120 x  64 0.001 BF
#   18 conv     64       1 x 1/ 1    160 x 120 x  64 ->  160 x 120 x  64 0.157 BF
#   19 conv     64       3 x 3/ 1    160 x 120 x  64 ->  160 x 120 x  64 1.416 BF
#   20 Shortcut Layer: 17,  wt = 0, wn = 0, outputs: 160 x 120 x  64 0.001 BF
#   21 conv     64       1 x 1/ 1    160 x 120 x  64 ->  160 x 120 x  64 0.157 BF
#   22 route  21 12 	                           ->  160 x 120 x 128
#   23 conv    128       1 x 1/ 1    160 x 120 x 128 ->  160 x 120 x 128 0.629 BF
#   24 conv    256       3 x 3/ 2    160 x 120 x 128 ->   80 x  60 x 256 2.831 BF
#   25 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#   26 route  24 		                           ->   80 x  60 x 256
#   27 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#   28 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   29 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   31 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   32 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   34 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   35 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   37 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   38 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   39 Shortcut Layer: 36,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   40 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   41 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   42 Shortcut Layer: 39,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   43 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   44 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   45 Shortcut Layer: 42,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   46 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   47 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   48 Shortcut Layer: 45,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   49 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   50 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   51 Shortcut Layer: 48,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   52 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   53 route  52 25 	                           ->   80 x  60 x 256
#   54 conv    256       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 256 0.629 BF
#   55 conv    512       3 x 3/ 2     80 x  60 x 256 ->   40 x  30 x 512 2.831 BF
#   56 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#   57 route  55 		                           ->   40 x  30 x 512
#   58 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#   59 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   60 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   62 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   63 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   64 Shortcut Layer: 61,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   65 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   66 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   67 Shortcut Layer: 64,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   68 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   69 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   70 Shortcut Layer: 67,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   71 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   72 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   73 Shortcut Layer: 70,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   74 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   75 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   76 Shortcut Layer: 73,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   77 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   78 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   79 Shortcut Layer: 76,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   80 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   81 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   82 Shortcut Layer: 79,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   83 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   84 route  83 56 	                           ->   40 x  30 x 512
#   85 conv    512       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 512 0.629 BF
#   86 conv   1024       3 x 3/ 2     40 x  30 x 512 ->   20 x  15 x1024 2.831 BF
#   87 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#   88 route  86 		                           ->   20 x  15 x1024
#   89 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#   90 conv    512       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.157 BF
#   91 conv    512       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x 512 1.416 BF
#   92 Shortcut Layer: 89,  wt = 0, wn = 0, outputs:  20 x  15 x 512 0.000 BF
#   93 conv    512       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.157 BF
#   94 conv    512       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x 512 1.416 BF
#   95 Shortcut Layer: 92,  wt = 0, wn = 0, outputs:  20 x  15 x 512 0.000 BF
#   96 conv    512       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.157 BF
#   97 conv    512       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x 512 1.416 BF
#   98 Shortcut Layer: 95,  wt = 0, wn = 0, outputs:  20 x  15 x 512 0.000 BF
#   99 conv    512       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.157 BF
#  100 conv    512       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x 512 1.416 BF
#  101 Shortcut Layer: 98,  wt = 0, wn = 0, outputs:  20 x  15 x 512 0.000 BF
#  102 conv    512       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.157 BF
#  103 route  102 87 	                           ->   20 x  15 x1024
#  104 conv   1024       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x1024 0.629 BF
#  105 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  106 conv   1024       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x1024 2.831 BF
#  107 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  108 max                5x 5/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.004 BF
#  109 route  107 		                           ->   20 x  15 x 512
#  110 max                9x 9/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.012 BF
#  111 route  107 		                           ->   20 x  15 x 512
#  112 max               13x13/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.026 BF
#  113 route  112 110 108 107 	                   ->   20 x  15 x2048
#  114 conv    512       1 x 1/ 1     20 x  15 x2048 ->   20 x  15 x 512 0.629 BF
#  115 conv   1024       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x1024 2.831 BF
#  116 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  117 conv    256       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 256 0.079 BF
#  118 upsample                 2x    20 x  15 x 256 ->   40 x  30 x 256
#  119 route  85 		                           ->   40 x  30 x 512
#  120 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  121 route  120 118 	                           ->   40 x  30 x 512
#  122 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  123 conv    512       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 512 2.831 BF
#  124 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  125 conv    512       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 512 2.831 BF
#  126 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  127 conv    128       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 128 0.079 BF
#  128 upsample                 2x    40 x  30 x 128 ->   80 x  60 x 128
#  129 route  54 		                           ->   80 x  60 x 256
#  130 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#  131 route  130 128 	                           ->   80 x  60 x 256
#  132 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#  133 conv    256       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 256 2.831 BF
#  134 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#  135 conv    256       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 256 2.831 BF
#  136 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#  137 conv    256       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 256 2.831 BF
#  138 conv     18       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x  18 0.044 BF
#  139 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.20
# nms_kind: greedynms (1), beta = 0.600000
#  140 route  136 		                           ->   80 x  60 x 128
#  141 conv    256       3 x 3/ 2     80 x  60 x 128 ->   40 x  30 x 256 0.708 BF
#  142 route  141 126 	                           ->   40 x  30 x 512
#  143 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  144 conv    512       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 512 2.831 BF
#  145 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  146 conv    512       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 512 2.831 BF
#  147 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  148 conv    512       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 512 2.831 BF
#  149 conv     18       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x  18 0.022 BF
#  150 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.10
# nms_kind: greedynms (1), beta = 0.600000
#  151 route  147 		                           ->   40 x  30 x 256
#  152 conv    512       3 x 3/ 2     40 x  30 x 256 ->   20 x  15 x 512 0.708 BF
#  153 route  152 116 	                           ->   20 x  15 x1024
#  154 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  155 conv   1024       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x1024 2.831 BF
#  156 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  157 conv   1024       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x1024 2.831 BF
#  158 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  159 conv   1024       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x1024 2.831 BF
#  160 conv     18       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x  18 0.011 BF
#  161 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
# Unused field: 'random = 1'
# Total BFLOPS 105.733
# avg_outputs = 869429
#  Allocate additional workspace_size = 52.43 MB
# yolov4-obj
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 2, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    640 x 480 x   3 ->  640 x 480 x  32 0.531 BF
#    1 conv     64       3 x 3/ 2    640 x 480 x  32 ->  320 x 240 x  64 2.831 BF
#    2 conv     64       1 x 1/ 1    320 x 240 x  64 ->  320 x 240 x  64 0.629 BF
#    3 route  1 		                           ->  320 x 240 x  64
#    4 conv     64       1 x 1/ 1    320 x 240 x  64 ->  320 x 240 x  64 0.629 BF
#    5 conv     32       1 x 1/ 1    320 x 240 x  64 ->  320 x 240 x  32 0.315 BF
#    6 conv     64       3 x 3/ 1    320 x 240 x  32 ->  320 x 240 x  64 2.831 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 320 x 240 x  64 0.005 BF
#    8 conv     64       1 x 1/ 1    320 x 240 x  64 ->  320 x 240 x  64 0.629 BF
#    9 route  8 2 	                           ->  320 x 240 x 128
#   10 conv     64       1 x 1/ 1    320 x 240 x 128 ->  320 x 240 x  64 1.258 BF
#   11 conv    128       3 x 3/ 2    320 x 240 x  64 ->  160 x 120 x 128 2.831 BF
#   12 conv     64       1 x 1/ 1    160 x 120 x 128 ->  160 x 120 x  64 0.315 BF
#   13 route  11 		                           ->  160 x 120 x 128
#   14 conv     64       1 x 1/ 1    160 x 120 x 128 ->  160 x 120 x  64 0.315 BF
#   15 conv     64       1 x 1/ 1    160 x 120 x  64 ->  160 x 120 x  64 0.157 BF
#   16 conv     64       3 x 3/ 1    160 x 120 x  64 ->  160 x 120 x  64 1.416 BF
#   17 Shortcut Layer: 14,  wt = 0, wn = 0, outputs: 160 x 120 x  64 0.001 BF
#   18 conv     64       1 x 1/ 1    160 x 120 x  64 ->  160 x 120 x  64 0.157 BF
#   19 conv     64       3 x 3/ 1    160 x 120 x  64 ->  160 x 120 x  64 1.416 BF
#   20 Shortcut Layer: 17,  wt = 0, wn = 0, outputs: 160 x 120 x  64 0.001 BF
#   21 conv     64       1 x 1/ 1    160 x 120 x  64 ->  160 x 120 x  64 0.157 BF
#   22 route  21 12 	                           ->  160 x 120 x 128
#   23 conv    128       1 x 1/ 1    160 x 120 x 128 ->  160 x 120 x 128 0.629 BF
#   24 conv    256       3 x 3/ 2    160 x 120 x 128 ->   80 x  60 x 256 2.831 BF
#   25 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#   26 route  24 		                           ->   80 x  60 x 256
#   27 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#   28 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   29 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   31 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   32 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   34 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   35 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   37 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   38 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   39 Shortcut Layer: 36,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   40 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   41 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   42 Shortcut Layer: 39,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   43 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   44 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   45 Shortcut Layer: 42,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   46 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   47 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   48 Shortcut Layer: 45,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   49 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   50 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   51 Shortcut Layer: 48,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   52 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   53 route  52 25 	                           ->   80 x  60 x 256
#   54 conv    256       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 256 0.629 BF
#   55 conv    512       3 x 3/ 2     80 x  60 x 256 ->   40 x  30 x 512 2.831 BF
#   56 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#   57 route  55 		                           ->   40 x  30 x 512
#   58 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#   59 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   60 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   62 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   63 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   64 Shortcut Layer: 61,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   65 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   66 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   67 Shortcut Layer: 64,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   68 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   69 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   70 Shortcut Layer: 67,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   71 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   72 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   73 Shortcut Layer: 70,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   74 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   75 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   76 Shortcut Layer: 73,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   77 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   78 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   79 Shortcut Layer: 76,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   80 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   81 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   82 Shortcut Layer: 79,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   83 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   84 route  83 56 	                           ->   40 x  30 x 512
#   85 conv    512       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 512 0.629 BF
#   86 conv   1024       3 x 3/ 2     40 x  30 x 512 ->   20 x  15 x1024 2.831 BF
#   87 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#   88 route  86 		                           ->   20 x  15 x1024
#   89 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#   90 conv    512       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.157 BF
#   91 conv    512       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x 512 1.416 BF
#   92 Shortcut Layer: 89,  wt = 0, wn = 0, outputs:  20 x  15 x 512 0.000 BF
#   93 conv    512       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.157 BF
#   94 conv    512       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x 512 1.416 BF
#   95 Shortcut Layer: 92,  wt = 0, wn = 0, outputs:  20 x  15 x 512 0.000 BF
#   96 conv    512       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.157 BF
#   97 conv    512       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x 512 1.416 BF
#   98 Shortcut Layer: 95,  wt = 0, wn = 0, outputs:  20 x  15 x 512 0.000 BF
#   99 conv    512       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.157 BF
#  100 conv    512       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x 512 1.416 BF
#  101 Shortcut Layer: 98,  wt = 0, wn = 0, outputs:  20 x  15 x 512 0.000 BF
#  102 conv    512       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.157 BF
#  103 route  102 87 	                           ->   20 x  15 x1024
#  104 conv   1024       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x1024 0.629 BF
#  105 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  106 conv   1024       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x1024 2.831 BF
#  107 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  108 max                5x 5/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.004 BF
#  109 route  107 		                           ->   20 x  15 x 512
#  110 max                9x 9/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.012 BF
#  111 route  107 		                           ->   20 x  15 x 512
#  112 max               13x13/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.026 BF
#  113 route  112 110 108 107 	                   ->   20 x  15 x2048
#  114 conv    512       1 x 1/ 1     20 x  15 x2048 ->   20 x  15 x 512 0.629 BF
#  115 conv   1024       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x1024 2.831 BF
#  116 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  117 conv    256       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 256 0.079 BF
#  118 upsample                 2x    20 x  15 x 256 ->   40 x  30 x 256
#  119 route  85 		                           ->   40 x  30 x 512
#  120 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  121 route  120 118 	                           ->   40 x  30 x 512
#  122 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  123 conv    512       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 512 2.831 BF
#  124 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  125 conv    512       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 512 2.831 BF
#  126 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  127 conv    128       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 128 0.079 BF
#  128 upsample                 2x    40 x  30 x 128 ->   80 x  60 x 128
#  129 route  54 		                           ->   80 x  60 x 256
#  130 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#  131 route  130 128 	                           ->   80 x  60 x 256
#  132 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#  133 conv    256       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 256 2.831 BF
#  134 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#  135 conv    256       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 256 2.831 BF
#  136 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#  137 conv    256       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 256 2.831 BF
#  138 conv     18       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x  18 0.044 BF
#  139 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.20
# nms_kind: greedynms (1), beta = 0.600000
#  140 route  136 		                           ->   80 x  60 x 128
#  141 conv    256       3 x 3/ 2     80 x  60 x 128 ->   40 x  30 x 256 0.708 BF
#  142 route  141 126 	                           ->   40 x  30 x 512
#  143 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  144 conv    512       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 512 2.831 BF
#  145 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  146 conv    512       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 512 2.831 BF
#  147 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  148 conv    512       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 512 2.831 BF
#  149 conv     18       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x  18 0.022 BF
#  150 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.10
# nms_kind: greedynms (1), beta = 0.600000
#  151 route  147 		                           ->   40 x  30 x 256
#  152 conv    512       3 x 3/ 2     40 x  30 x 256 ->   20 x  15 x 512 0.708 BF
#  153 route  152 116 	                           ->   20 x  15 x1024
#  154 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  155 conv   1024       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x1024 2.831 BF
#  156 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  157 conv   1024       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x1024 2.831 BF
#  158 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  159 conv   1024       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x1024 2.831 BF
#  160 conv     18       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x  18 0.011 BF
#  161 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
# Unused field: 'random = 1'
# Total BFLOPS 105.733
# avg_outputs = 869429
#  Allocate additional workspace_size = 98.80 MB
# Loading weights from backup/yolov4-obj_last.weights...
#  seen 64, trained: 160 K-images (2 Kilo-batches_64)
# Done! Loaded 162 layers from weights-file
# Learning Rate: 0.001, Momentum: 0.949, Decay: 0.0005
#  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
# Resizing, random_coef = 1.40
#
#  928 x 704
#  Create 6 permanent cpu-threads

# %% [markdown]
# 推論(サンプル)

# %%
# !./darknet detector\
  test\
  cfg/coco.data\
  cfg/yolov4.cfg\
  yolov4.weights\
  data/dog.jpg
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
#    8 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    9 route  8 2 	                           ->  304 x 304 x 128
#   10 conv     64       1 x 1/ 1    304 x 304 x 128 ->  304 x 304 x  64 1.514 BF
#   11 conv    128       3 x 3/ 2    304 x 304 x  64 ->  152 x 152 x 128 3.407 BF
#   12 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#   13 route  11 		                           ->  152 x 152 x 128
#   14 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#   15 conv     64       1 x 1/ 1    152 x 152 x  64 ->  152 x 152 x  64 0.189 BF
#   16 conv     64       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x  64 1.703 BF
#   17 Shortcut Layer: 14,  wt = 0, wn = 0, outputs: 152 x 152 x  64 0.001 BF
#   18 conv     64       1 x 1/ 1    152 x 152 x  64 ->  152 x 152 x  64 0.189 BF
#   19 conv     64       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x  64 1.703 BF
#   20 Shortcut Layer: 17,  wt = 0, wn = 0, outputs: 152 x 152 x  64 0.001 BF
#   21 conv     64       1 x 1/ 1    152 x 152 x  64 ->  152 x 152 x  64 0.189 BF
#   22 route  21 12 	                           ->  152 x 152 x 128
#   23 conv    128       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x 128 0.757 BF
#   24 conv    256       3 x 3/ 2    152 x 152 x 128 ->   76 x  76 x 256 3.407 BF
#   25 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   26 route  24 		                           ->   76 x  76 x 256
#   27 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   28 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   29 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   31 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   32 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   34 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   35 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   37 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   38 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   39 Shortcut Layer: 36,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   40 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   41 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   42 Shortcut Layer: 39,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   43 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   44 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   45 Shortcut Layer: 42,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   46 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   47 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   48 Shortcut Layer: 45,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   49 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   50 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   51 Shortcut Layer: 48,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   52 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   53 route  52 25 	                           ->   76 x  76 x 256
#   54 conv    256       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 256 0.757 BF
#   55 conv    512       3 x 3/ 2     76 x  76 x 256 ->   38 x  38 x 512 3.407 BF
#   56 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   57 route  55 		                           ->   38 x  38 x 512
#   58 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   59 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   60 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   62 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   63 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   64 Shortcut Layer: 61,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   65 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   66 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   67 Shortcut Layer: 64,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   68 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   69 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   70 Shortcut Layer: 67,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   71 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   72 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   73 Shortcut Layer: 70,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   74 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   75 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   76 Shortcut Layer: 73,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   77 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   78 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   79 Shortcut Layer: 76,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   80 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   81 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   82 Shortcut Layer: 79,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   83 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   84 route  83 56 	                           ->   38 x  38 x 512
#   85 conv    512       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 512 0.757 BF
#   86 conv   1024       3 x 3/ 2     38 x  38 x 512 ->   19 x  19 x1024 3.407 BF
#   87 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   88 route  86 		                           ->   19 x  19 x1024
#   89 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   90 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#   91 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#   92 Shortcut Layer: 89,  wt = 0, wn = 0, outputs:  19 x  19 x 512 0.000 BF
#   93 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#   94 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#   95 Shortcut Layer: 92,  wt = 0, wn = 0, outputs:  19 x  19 x 512 0.000 BF
#   96 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#   97 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#   98 Shortcut Layer: 95,  wt = 0, wn = 0, outputs:  19 x  19 x 512 0.000 BF
#   99 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#  100 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#  101 Shortcut Layer: 98,  wt = 0, wn = 0, outputs:  19 x  19 x 512 0.000 BF
#  102 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#  103 route  102 87 	                           ->   19 x  19 x1024
#  104 conv   1024       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x1024 0.757 BF
#  105 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  106 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  107 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  108 max                5x 5/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.005 BF
#  109 route  107 		                           ->   19 x  19 x 512
#  110 max                9x 9/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.015 BF
#  111 route  107 		                           ->   19 x  19 x 512
#  112 max               13x13/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.031 BF
#  113 route  112 110 108 107 	                   ->   19 x  19 x2048
#  114 conv    512       1 x 1/ 1     19 x  19 x2048 ->   19 x  19 x 512 0.757 BF
#  115 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  116 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  117 conv    256       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 256 0.095 BF
#  118 upsample                 2x    19 x  19 x 256 ->   38 x  38 x 256
#  119 route  85 		                           ->   38 x  38 x 512
#  120 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  121 route  120 118 	                           ->   38 x  38 x 512
#  122 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  123 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  124 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  125 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  126 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  127 conv    128       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 128 0.095 BF
#  128 upsample                 2x    38 x  38 x 128 ->   76 x  76 x 128
#  129 route  54 		                           ->   76 x  76 x 256
#  130 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  131 route  130 128 	                           ->   76 x  76 x 256
#  132 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  133 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  134 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  135 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  136 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  137 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  138 conv    255       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 255 0.754 BF
#  139 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.20
# nms_kind: greedynms (1), beta = 0.600000
#  140 route  136 		                           ->   76 x  76 x 128
#  141 conv    256       3 x 3/ 2     76 x  76 x 128 ->   38 x  38 x 256 0.852 BF
#  142 route  141 126 	                           ->   38 x  38 x 512
#  143 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  144 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  145 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  146 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  147 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  148 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  149 conv    255       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 255 0.377 BF
#  150 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.10
# nms_kind: greedynms (1), beta = 0.600000
#  151 route  147 		                           ->   38 x  38 x 256
#  152 conv    512       3 x 3/ 2     38 x  38 x 256 ->   19 x  19 x 512 0.852 BF
#  153 route  152 116 	                           ->   19 x  19 x1024
#  154 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  155 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  156 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  157 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  158 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  159 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  160 conv    255       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 255 0.189 BF
#  161 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
# Total BFLOPS 128.459
# avg_outputs = 1068395
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from yolov4.weights...
#  seen 64, trained: 32032 K-images (500 Kilo-batches_64)
# Done! Loaded 162 layers from weights-file
#  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
# data/dog.jpg: Predicted in 54.838000 milli-seconds.
# bicycle: 92%
# dog: 98%
# truck: 92%
# pottedplant: 33%
# Unable to init server: Could not connect: Connection refused
#
# (predictions:246): Gtk-WARNING **: 09:06:56.489: cannot open display:

# %% [markdown]
# 推論(自前)

# %%
# !./darknet detector\
  test\
  data/obj.data\
  cfg/yolov4-obj-test.cfg\
  backup/yolov4-obj_final.weights\
  data/pumpkin/135.png
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    640 x 480 x   3 ->  640 x 480 x  32 0.531 BF
#    1 conv     64       3 x 3/ 2    640 x 480 x  32 ->  320 x 240 x  64 2.831 BF
#    2 conv     64       1 x 1/ 1    320 x 240 x  64 ->  320 x 240 x  64 0.629 BF
#    3 route  1 		                           ->  320 x 240 x  64
#    4 conv     64       1 x 1/ 1    320 x 240 x  64 ->  320 x 240 x  64 0.629 BF
#    5 conv     32       1 x 1/ 1    320 x 240 x  64 ->  320 x 240 x  32 0.315 BF
#    6 conv     64       3 x 3/ 1    320 x 240 x  32 ->  320 x 240 x  64 2.831 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 320 x 240 x  64 0.005 BF
#    8 conv     64       1 x 1/ 1    320 x 240 x  64 ->  320 x 240 x  64 0.629 BF
#    9 route  8 2 	                           ->  320 x 240 x 128
#   10 conv     64       1 x 1/ 1    320 x 240 x 128 ->  320 x 240 x  64 1.258 BF
#   11 conv    128       3 x 3/ 2    320 x 240 x  64 ->  160 x 120 x 128 2.831 BF
#   12 conv     64       1 x 1/ 1    160 x 120 x 128 ->  160 x 120 x  64 0.315 BF
#   13 route  11 		                           ->  160 x 120 x 128
#   14 conv     64       1 x 1/ 1    160 x 120 x 128 ->  160 x 120 x  64 0.315 BF
#   15 conv     64       1 x 1/ 1    160 x 120 x  64 ->  160 x 120 x  64 0.157 BF
#   16 conv     64       3 x 3/ 1    160 x 120 x  64 ->  160 x 120 x  64 1.416 BF
#   17 Shortcut Layer: 14,  wt = 0, wn = 0, outputs: 160 x 120 x  64 0.001 BF
#   18 conv     64       1 x 1/ 1    160 x 120 x  64 ->  160 x 120 x  64 0.157 BF
#   19 conv     64       3 x 3/ 1    160 x 120 x  64 ->  160 x 120 x  64 1.416 BF
#   20 Shortcut Layer: 17,  wt = 0, wn = 0, outputs: 160 x 120 x  64 0.001 BF
#   21 conv     64       1 x 1/ 1    160 x 120 x  64 ->  160 x 120 x  64 0.157 BF
#   22 route  21 12 	                           ->  160 x 120 x 128
#   23 conv    128       1 x 1/ 1    160 x 120 x 128 ->  160 x 120 x 128 0.629 BF
#   24 conv    256       3 x 3/ 2    160 x 120 x 128 ->   80 x  60 x 256 2.831 BF
#   25 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#   26 route  24 		                           ->   80 x  60 x 256
#   27 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#   28 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   29 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   31 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   32 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   34 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   35 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   37 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   38 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   39 Shortcut Layer: 36,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   40 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   41 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   42 Shortcut Layer: 39,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   43 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   44 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   45 Shortcut Layer: 42,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   46 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   47 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   48 Shortcut Layer: 45,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   49 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   50 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   51 Shortcut Layer: 48,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   52 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   53 route  52 25 	                           ->   80 x  60 x 256
#   54 conv    256       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 256 0.629 BF
#   55 conv    512       3 x 3/ 2     80 x  60 x 256 ->   40 x  30 x 512 2.831 BF
#   56 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#   57 route  55 		                           ->   40 x  30 x 512
#   58 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#   59 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   60 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   62 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   63 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   64 Shortcut Layer: 61,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   65 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   66 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   67 Shortcut Layer: 64,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   68 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   69 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   70 Shortcut Layer: 67,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   71 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   72 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   73 Shortcut Layer: 70,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   74 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   75 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   76 Shortcut Layer: 73,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   77 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   78 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   79 Shortcut Layer: 76,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   80 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   81 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   82 Shortcut Layer: 79,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   83 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   84 route  83 56 	                           ->   40 x  30 x 512
#   85 conv    512       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 512 0.629 BF
#   86 conv   1024       3 x 3/ 2     40 x  30 x 512 ->   20 x  15 x1024 2.831 BF
#   87 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#   88 route  86 		                           ->   20 x  15 x1024
#   89 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#   90 conv    512       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.157 BF
#   91 conv    512       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x 512 1.416 BF
#   92 Shortcut Layer: 89,  wt = 0, wn = 0, outputs:  20 x  15 x 512 0.000 BF
#   93 conv    512       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.157 BF
#   94 conv    512       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x 512 1.416 BF
#   95 Shortcut Layer: 92,  wt = 0, wn = 0, outputs:  20 x  15 x 512 0.000 BF
#   96 conv    512       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.157 BF
#   97 conv    512       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x 512 1.416 BF
#   98 Shortcut Layer: 95,  wt = 0, wn = 0, outputs:  20 x  15 x 512 0.000 BF
#   99 conv    512       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.157 BF
#  100 conv    512       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x 512 1.416 BF
#  101 Shortcut Layer: 98,  wt = 0, wn = 0, outputs:  20 x  15 x 512 0.000 BF
#  102 conv    512       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.157 BF
#  103 route  102 87 	                           ->   20 x  15 x1024
#  104 conv   1024       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x1024 0.629 BF
#  105 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  106 conv   1024       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x1024 2.831 BF
#  107 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  108 max                5x 5/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.004 BF
#  109 route  107 		                           ->   20 x  15 x 512
#  110 max                9x 9/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.012 BF
#  111 route  107 		                           ->   20 x  15 x 512
#  112 max               13x13/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.026 BF
#  113 route  112 110 108 107 	                   ->   20 x  15 x2048
#  114 conv    512       1 x 1/ 1     20 x  15 x2048 ->   20 x  15 x 512 0.629 BF
#  115 conv   1024       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x1024 2.831 BF
#  116 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  117 conv    256       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 256 0.079 BF
#  118 upsample                 2x    20 x  15 x 256 ->   40 x  30 x 256
#  119 route  85 		                           ->   40 x  30 x 512
#  120 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  121 route  120 118 	                           ->   40 x  30 x 512
#  122 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  123 conv    512       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 512 2.831 BF
#  124 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  125 conv    512       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 512 2.831 BF
#  126 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  127 conv    128       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 128 0.079 BF
#  128 upsample                 2x    40 x  30 x 128 ->   80 x  60 x 128
#  129 route  54 		                           ->   80 x  60 x 256
#  130 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#  131 route  130 128 	                           ->   80 x  60 x 256
#  132 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#  133 conv    256       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 256 2.831 BF
#  134 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#  135 conv    256       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 256 2.831 BF
#  136 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#  137 conv    256       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 256 2.831 BF
#  138 conv     18       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x  18 0.044 BF
#  139 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.20
# nms_kind: greedynms (1), beta = 0.600000
#  140 route  136 		                           ->   80 x  60 x 128
#  141 conv    256       3 x 3/ 2     80 x  60 x 128 ->   40 x  30 x 256 0.708 BF
#  142 route  141 126 	                           ->   40 x  30 x 512
#  143 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  144 conv    512       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 512 2.831 BF
#  145 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  146 conv    512       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 512 2.831 BF
#  147 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  148 conv    512       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 512 2.831 BF
#  149 conv     18       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x  18 0.022 BF
#  150 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.10
# nms_kind: greedynms (1), beta = 0.600000
#  151 route  147 		                           ->   40 x  30 x 256
#  152 conv    512       3 x 3/ 2     40 x  30 x 256 ->   20 x  15 x 512 0.708 BF
#  153 route  152 116 	                           ->   20 x  15 x1024
#  154 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  155 conv   1024       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x1024 2.831 BF
#  156 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  157 conv   1024       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x1024 2.831 BF
#  158 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  159 conv   1024       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x1024 2.831 BF
#  160 conv     18       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x  18 0.011 BF
#  161 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
# Unused field: 'random = 1'
# Total BFLOPS 105.733
# avg_outputs = 869429
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from backup/yolov4-obj_final.weights...
#  seen 64, trained: 448 K-images (7 Kilo-batches_64)
# Done! Loaded 162 layers from weights-file
#  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
# data/pumpkin/135.png: Predicted in 27.663000 milli-seconds.
# pumpkin: 100%
# pumpkin: 100%
# pumpkin: 100%
# pumpkin: 100%
# pumpkin: 100%
# Unable to init server: Could not connect: Connection refused
#
# (predictions:998): Gtk-WARNING **: 12:27:36.374: cannot open display:

# %% [markdown]
# 評価

# %%
# !./darknet detector\
  map\
  data/obj.data\
  cfg/yolov4-obj-test.cfg\
  backup/yolov4-obj_final.weights
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    640 x 480 x   3 ->  640 x 480 x  32 0.531 BF
#    1 conv     64       3 x 3/ 2    640 x 480 x  32 ->  320 x 240 x  64 2.831 BF
#    2 conv     64       1 x 1/ 1    320 x 240 x  64 ->  320 x 240 x  64 0.629 BF
#    3 route  1 		                           ->  320 x 240 x  64
#    4 conv     64       1 x 1/ 1    320 x 240 x  64 ->  320 x 240 x  64 0.629 BF
#    5 conv     32       1 x 1/ 1    320 x 240 x  64 ->  320 x 240 x  32 0.315 BF
#    6 conv     64       3 x 3/ 1    320 x 240 x  32 ->  320 x 240 x  64 2.831 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 320 x 240 x  64 0.005 BF
#    8 conv     64       1 x 1/ 1    320 x 240 x  64 ->  320 x 240 x  64 0.629 BF
#    9 route  8 2 	                           ->  320 x 240 x 128
#   10 conv     64       1 x 1/ 1    320 x 240 x 128 ->  320 x 240 x  64 1.258 BF
#   11 conv    128       3 x 3/ 2    320 x 240 x  64 ->  160 x 120 x 128 2.831 BF
#   12 conv     64       1 x 1/ 1    160 x 120 x 128 ->  160 x 120 x  64 0.315 BF
#   13 route  11 		                           ->  160 x 120 x 128
#   14 conv     64       1 x 1/ 1    160 x 120 x 128 ->  160 x 120 x  64 0.315 BF
#   15 conv     64       1 x 1/ 1    160 x 120 x  64 ->  160 x 120 x  64 0.157 BF
#   16 conv     64       3 x 3/ 1    160 x 120 x  64 ->  160 x 120 x  64 1.416 BF
#   17 Shortcut Layer: 14,  wt = 0, wn = 0, outputs: 160 x 120 x  64 0.001 BF
#   18 conv     64       1 x 1/ 1    160 x 120 x  64 ->  160 x 120 x  64 0.157 BF
#   19 conv     64       3 x 3/ 1    160 x 120 x  64 ->  160 x 120 x  64 1.416 BF
#   20 Shortcut Layer: 17,  wt = 0, wn = 0, outputs: 160 x 120 x  64 0.001 BF
#   21 conv     64       1 x 1/ 1    160 x 120 x  64 ->  160 x 120 x  64 0.157 BF
#   22 route  21 12 	                           ->  160 x 120 x 128
#   23 conv    128       1 x 1/ 1    160 x 120 x 128 ->  160 x 120 x 128 0.629 BF
#   24 conv    256       3 x 3/ 2    160 x 120 x 128 ->   80 x  60 x 256 2.831 BF
#   25 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#   26 route  24 		                           ->   80 x  60 x 256
#   27 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#   28 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   29 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   31 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   32 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   34 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   35 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   37 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   38 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   39 Shortcut Layer: 36,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   40 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   41 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   42 Shortcut Layer: 39,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   43 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   44 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   45 Shortcut Layer: 42,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   46 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   47 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   48 Shortcut Layer: 45,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   49 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   50 conv    128       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 128 1.416 BF
#   51 Shortcut Layer: 48,  wt = 0, wn = 0, outputs:  80 x  60 x 128 0.001 BF
#   52 conv    128       1 x 1/ 1     80 x  60 x 128 ->   80 x  60 x 128 0.157 BF
#   53 route  52 25 	                           ->   80 x  60 x 256
#   54 conv    256       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 256 0.629 BF
#   55 conv    512       3 x 3/ 2     80 x  60 x 256 ->   40 x  30 x 512 2.831 BF
#   56 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#   57 route  55 		                           ->   40 x  30 x 512
#   58 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#   59 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   60 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   62 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   63 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   64 Shortcut Layer: 61,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   65 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   66 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   67 Shortcut Layer: 64,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   68 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   69 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   70 Shortcut Layer: 67,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   71 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   72 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   73 Shortcut Layer: 70,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   74 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   75 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   76 Shortcut Layer: 73,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   77 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   78 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   79 Shortcut Layer: 76,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   80 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   81 conv    256       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 256 1.416 BF
#   82 Shortcut Layer: 79,  wt = 0, wn = 0, outputs:  40 x  30 x 256 0.000 BF
#   83 conv    256       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 256 0.157 BF
#   84 route  83 56 	                           ->   40 x  30 x 512
#   85 conv    512       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 512 0.629 BF
#   86 conv   1024       3 x 3/ 2     40 x  30 x 512 ->   20 x  15 x1024 2.831 BF
#   87 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#   88 route  86 		                           ->   20 x  15 x1024
#   89 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#   90 conv    512       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.157 BF
#   91 conv    512       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x 512 1.416 BF
#   92 Shortcut Layer: 89,  wt = 0, wn = 0, outputs:  20 x  15 x 512 0.000 BF
#   93 conv    512       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.157 BF
#   94 conv    512       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x 512 1.416 BF
#   95 Shortcut Layer: 92,  wt = 0, wn = 0, outputs:  20 x  15 x 512 0.000 BF
#   96 conv    512       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.157 BF
#   97 conv    512       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x 512 1.416 BF
#   98 Shortcut Layer: 95,  wt = 0, wn = 0, outputs:  20 x  15 x 512 0.000 BF
#   99 conv    512       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.157 BF
#  100 conv    512       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x 512 1.416 BF
#  101 Shortcut Layer: 98,  wt = 0, wn = 0, outputs:  20 x  15 x 512 0.000 BF
#  102 conv    512       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.157 BF
#  103 route  102 87 	                           ->   20 x  15 x1024
#  104 conv   1024       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x1024 0.629 BF
#  105 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  106 conv   1024       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x1024 2.831 BF
#  107 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  108 max                5x 5/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.004 BF
#  109 route  107 		                           ->   20 x  15 x 512
#  110 max                9x 9/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.012 BF
#  111 route  107 		                           ->   20 x  15 x 512
#  112 max               13x13/ 1     20 x  15 x 512 ->   20 x  15 x 512 0.026 BF
#  113 route  112 110 108 107 	                   ->   20 x  15 x2048
#  114 conv    512       1 x 1/ 1     20 x  15 x2048 ->   20 x  15 x 512 0.629 BF
#  115 conv   1024       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x1024 2.831 BF
#  116 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  117 conv    256       1 x 1/ 1     20 x  15 x 512 ->   20 x  15 x 256 0.079 BF
#  118 upsample                 2x    20 x  15 x 256 ->   40 x  30 x 256
#  119 route  85 		                           ->   40 x  30 x 512
#  120 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  121 route  120 118 	                           ->   40 x  30 x 512
#  122 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  123 conv    512       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 512 2.831 BF
#  124 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  125 conv    512       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 512 2.831 BF
#  126 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  127 conv    128       1 x 1/ 1     40 x  30 x 256 ->   40 x  30 x 128 0.079 BF
#  128 upsample                 2x    40 x  30 x 128 ->   80 x  60 x 128
#  129 route  54 		                           ->   80 x  60 x 256
#  130 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#  131 route  130 128 	                           ->   80 x  60 x 256
#  132 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#  133 conv    256       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 256 2.831 BF
#  134 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#  135 conv    256       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 256 2.831 BF
#  136 conv    128       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x 128 0.315 BF
#  137 conv    256       3 x 3/ 1     80 x  60 x 128 ->   80 x  60 x 256 2.831 BF
#  138 conv     18       1 x 1/ 1     80 x  60 x 256 ->   80 x  60 x  18 0.044 BF
#  139 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.20
# nms_kind: greedynms (1), beta = 0.600000
#  140 route  136 		                           ->   80 x  60 x 128
#  141 conv    256       3 x 3/ 2     80 x  60 x 128 ->   40 x  30 x 256 0.708 BF
#  142 route  141 126 	                           ->   40 x  30 x 512
#  143 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  144 conv    512       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 512 2.831 BF
#  145 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  146 conv    512       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 512 2.831 BF
#  147 conv    256       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x 256 0.315 BF
#  148 conv    512       3 x 3/ 1     40 x  30 x 256 ->   40 x  30 x 512 2.831 BF
#  149 conv     18       1 x 1/ 1     40 x  30 x 512 ->   40 x  30 x  18 0.022 BF
#  150 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.10
# nms_kind: greedynms (1), beta = 0.600000
#  151 route  147 		                           ->   40 x  30 x 256
#  152 conv    512       3 x 3/ 2     40 x  30 x 256 ->   20 x  15 x 512 0.708 BF
#  153 route  152 116 	                           ->   20 x  15 x1024
#  154 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  155 conv   1024       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x1024 2.831 BF
#  156 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  157 conv   1024       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x1024 2.831 BF
#  158 conv    512       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x 512 0.315 BF
#  159 conv   1024       3 x 3/ 1     20 x  15 x 512 ->   20 x  15 x1024 2.831 BF
#  160 conv     18       1 x 1/ 1     20 x  15 x1024 ->   20 x  15 x  18 0.011 BF
#  161 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
# Unused field: 'random = 1'
# Total BFLOPS 105.733
# avg_outputs = 869429
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from backup/yolov4-obj_final.weights...
#  seen 64, trained: 448 K-images (7 Kilo-batches_64)
# Done! Loaded 162 layers from weights-file
#
#  calculation mAP (mean average precision)...
#  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
# 32
#  detections_count = 210, unique_truth_count = 180
# class_id = 0, name = pumpkin, ap = 98.76%   	 (TP = 177, FP = 10)
#
#  for conf_thresh = 0.25, precision = 0.95, recall = 0.98, F1-score = 0.96
#  for conf_thresh = 0.25, TP = 177, FP = 10, FN = 3, average IoU = 86.25 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.987606, or 98.76 %
# Total Detection Time: 1 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset
